# %%
import numpy as np
import pandas as pd

# %%
### Collecting the data from different sources

#### Train Data 
data1=pd.read_csv('data/water_solubility_data.csv')
data2=pd.read_csv('data/data_paper.csv',encoding='latin1')
data5 = pd.read_excel('data/Supplementary_data.xlsx')
data6=pd.read_csv('data/dataset-not-FA.csv')

### Test data 
test_set=pd.read_csv('data/dataset-E.csv')

# %%
### Size of each dataset 
print(data1.shape)
print(data2.shape)
print(data5.shape)
print(data6.shape)
print(test_set.shape)
# Out:
# (900, 12)
# (11862, 26)
# (9943, 6)
# (6154, 9)
# (1291, 6)

# %%
### In order to merge the data all the dataset should have identical column name ... 
data1=data1[['Smiles','LogS']]
## Changing the column name to be the identical with other dataset 
data1=data1.rename(columns={ "Smiles": "SMILES","LogS":"Solubility"})

### Selecting the requiered column 
data2=data2[['SMILES','LogS']]
## Changing the column name to be the identical with other dataset 
data2=data2.rename(columns={ "LogS":"Solubility"})#

### Changing the column name ...

data5=data5[['SMILES','logS']]
data5 = data5.rename(columns={'logS': 'Solubility'})

data6=data6[['SMILES','Solubility']]

# %%
### Merging the train dataset to one dataframe 
frames = [data1,data2,data5,data6]
train_set = pd.concat(frames)
### Size of the train and test dataset before preprocess....
print('Size of the train dataset :',len(train_set))
print('Size of the test dataset :',len(test_set))


train_set.to_csv('data/train4_final.csv')
test_set.to_csv('data/test_final.csv')
# Out:
# Size of the train dataset : 28859
# Size of the test dataset : 1291

# %%
train_set.reset_index(drop=True)
test_set.reset_index(drop=True)
# Out:
#           ID                Name  \
# 0        E-1           n-pentane
# 1        E-2        cyclopentane
# 2        E-3            n-hexane
# 3        E-4     2-methylpentane
# 4        E-5  2,2-dimethylbutane
# ...      ...                 ...
# 1286  E-1287           malathion
# 1287  E-1288       chlorpyriphos
# 1288  E-1289    prostaglandin_E2
# 1289  E-1290            p,p'-DDT
# 1290  E-1291           chlordane
#
#                                                   InChI  \
# 0                InChI=1S/C5H12/c1-3-5-4-2/h3-5H2,1-2H3
# 1                    InChI=1S/C5H10/c1-2-4-5-3-1/h1-5H2
# 2              InChI=1S/C6H14/c1-3-5-6-4-2/h3-6H2,1-2H3
# 3           InChI=1S/C6H14/c1-4-5-6(2)3/h6H,4-5H2,1-3H3
# 4                InChI=1S/C6H14/c1-5-6(2,3)4/h5H2,1-4H3
# ...                                                 ...
# 1286  InChI=1S/C10H19O6PS2/c1-5-15-9(11)7-8(10(12)16...
# 1287  InChI=1S/C9H11Cl3NO3PS/c1-3-14-17(18,15-4-2)16...
# 1288  InChI=1S/C20H32O5/c1-2-3-6-9-15(21)12-13-17-16...
# 1289  InChI=1S/C14H9Cl5/c15-11-5-1-9(2-6-11)13(14(17...
# 1290  InChI=1S/C10H6Cl8/c11-3-1-2-4(5(3)12)9(16)7(14...
#
#                          InChIKey  \
# 0     OFBQJSOFQDEBGM-UHFFFAOYSA-N
# 1     RGSFGYAAUTVSQA-UHFFFAOYSA-N
# 2     VLKZOEOYAKHREP-UHFFFAOYSA-N
# 3     AFABGHUZZDYHJO-UHFFFAOYSA-N
# 4     HNRMPXKDFBEGFZ-UHFFFAOYSA-N
# ...                           ...
# 1286  JXSJBGJIGXNWCI-UHFFFAOYSA-N
# 1287  SBPBAQFWLVIOKP-UHFFFAOYSA-N
# 1288  XEYBRNLFEZDVAW-UHFFFAOYSA-N
# 1289  YVGGHNCTFXOJCH-UHFFFAOYSA-N
# 1290  BIWJNBZANLAXMG-UHFFFAOYSA-N
#
#                                              SMILES  Solubility
# 0                                             CCCCC       -3.18
# 1                                           C1CCCC1       -2.64
# 2                                            CCCCCC       -3.84
# 3                                          CCCC(C)C       -3.74
# 4                                        CCC(C)(C)C       -3.55
# ...                                             ...         ...
# 1286               CCOC(=O)CC(SP(=S)(OC)OC)C(=O)OCC       -3.37
# 1287               CCOP(=S)(OCC)Oc1nc(Cl)c(Cl)cc1Cl       -5.49
# 1288        CCCCCC(O)C=CC1C(O)CC(=O)C1CC=CCCCC(=O)O       -2.47
# 1289   c(ccc(c1)Cl)(c1)C(c(ccc(c2)Cl)c2)C(Cl)(Cl)Cl       -7.15
# 1290  ClC1CC2C(C1Cl)C3(Cl)C(=C(Cl)C2(Cl)C3(Cl)Cl)Cl       -6.86
#
# [1291 rows x 6 columns]

# %%
from rdkit.Chem import MolFromSmiles as smi2mol
from rdkit.Chem import MolToSmiles as mol2smi
## Function to create canonical smiles 
def canon(smi):
    try:
        mol=smi2mol(smi, sanitize=True)
        smi_canon=mol2smi(mol, isomericSmiles=False, canonical=True)
        return(smi_canon)
    except:
        print("ERROR")
        return(smi)

# %%
#### Applying function to create the column with canonical smiles.  
train_set['smiles_canon'] = [canon(smi) for smi in train_set.SMILES]
test_set['smiles_canon'] = [canon(smi) for smi in test_set.SMILES]
# Out:
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors
# [10:38:53] WARNING: not removing hydrogen atom without neighbors

# %%
test_set[0:200]
# Out:
#         ID                Name  \
# 0      E-1           n-pentane
# 1      E-2        cyclopentane
# 2      E-3            n-hexane
# 3      E-4     2-methylpentane
# 4      E-5  2,2-dimethylbutane
# ..     ...                 ...
# 195  E-196       2,3',4',5-PCB
# 196  E-197       2,2',4,4'-PCB
# 197  E-198     2,2',3,3',4-PCB
# 198  E-199      2,2,4,6,6'-PCB
# 199  E-200     2,3',4,4',5-PCB
#
#                                                  InChI  \
# 0               InChI=1S/C5H12/c1-3-5-4-2/h3-5H2,1-2H3
# 1                   InChI=1S/C5H10/c1-2-4-5-3-1/h1-5H2
# 2             InChI=1S/C6H14/c1-3-5-6-4-2/h3-6H2,1-2H3
# 3          InChI=1S/C6H14/c1-4-5-6(2)3/h6H,4-5H2,1-3H3
# 4               InChI=1S/C6H14/c1-5-6(2,3)4/h5H2,1-4H3
# ..                                                 ...
# 195  InChI=1S/C12H6Cl4/c13-8-2-4-10(14)9(6-8)7-1-3-...
# 196  InChI=1S/C12H6Cl4/c13-7-1-3-9(11(15)5-7)10-4-2...
# 197  InChI=1S/C12H5Cl5/c13-8-3-1-6(5-10(8)15)7-2-4-...
# 198  InChI=1S/C12H5Cl5/c13-6-4-9(16)12(10(17)5-6)11...
# 199  InChI=1S/C12H5Cl5/c13-8-2-1-6(3-10(8)15)7-4-11...
#
#                         InChIKey                                SMILES  \
# 0    OFBQJSOFQDEBGM-UHFFFAOYSA-N                                 CCCCC
# 1    RGSFGYAAUTVSQA-UHFFFAOYSA-N                               C1CCCC1
# 2    VLKZOEOYAKHREP-UHFFFAOYSA-N                                CCCCCC
# 3    AFABGHUZZDYHJO-UHFFFAOYSA-N                              CCCC(C)C
# 4    HNRMPXKDFBEGFZ-UHFFFAOYSA-N                            CCC(C)(C)C
# ..                           ...                                   ...
# 195  KENZYIHFBRWMOD-UHFFFAOYSA-N      c1cc(Cl)c(Cl)cc1c2c(Cl)ccc(Cl)c2
# 196  QORAVNMWUNPXAO-UHFFFAOYSA-N      c1cc(Cl)cc(Cl)c1c2c(Cl)cc(Cl)cc2
# 197  WIDHRBRBACOVOY-UHFFFAOYSA-N  c1cc(Cl)c(Cl)cc1c2c(Cl)c(Cl)c(Cl)cc2
# 198  MTCPZNVSDFCBBE-UHFFFAOYSA-N      Clc1cccc(Cl)c1c2c(Cl)cc(Cl)cc2Cl
# 199  IUTPYMGCWINGEY-UHFFFAOYSA-N  c1cc(Cl)c(Cl)cc1c2c(Cl)cc(Cl)c(Cl)c2
#
#      Solubility                         smiles_canon
# 0         -3.18                                CCCCC
# 1         -2.64                              C1CCCC1
# 2         -3.84                               CCCCCC
# 3         -3.74                             CCCC(C)C
# 4         -3.55                           CCC(C)(C)C
# ..          ...                                  ...
# 195       -7.25    Clc1ccc(Cl)c(-c2ccc(Cl)c(Cl)c2)c1
# 196       -6.51      Clc1ccc(-c2ccc(Cl)cc2Cl)c(Cl)c1
# 197       -7.05    Clc1ccc(-c2ccc(Cl)c(Cl)c2Cl)cc1Cl
# 198       -7.32  Clc1cc(Cl)c(-c2c(Cl)cccc2Cl)c(Cl)c1
# 199       -7.39    Clc1ccc(-c2cc(Cl)c(Cl)cc2Cl)cc1Cl
#
# [200 rows x 7 columns]

# %%
### Calculate  the occurence of  smiles in both train and test dataset....
train_set['occurence'] = train_set.groupby('smiles_canon')['smiles_canon'].transform('count')
test_set['occurence'] = test_set.groupby('smiles_canon')['smiles_canon'].transform('count')

# %%
### Taking out Unique smiles from the train and test dataset 
train_set1= train_set[train_set['occurence']==1]
print(train_set1.shape)
test_set1= test_set[test_set['occurence']==1]
print(test_set1.shape)
# Out:
# (13432, 4)
# (1273, 8)

# %%
### Selecting specific column of the dataframe ..
train_set1=train_set1[['smiles_canon','Solubility','occurence']]
test_set1=test_set1[['smiles_canon','Solubility','occurence']]

# %%
#### Taking out the dataframe which has duplicate smiles means more than one time occurence in the dataset ...
train_set2= train_set[train_set['occurence']>1]
print(train_set2.shape)
test_set2= test_set[test_set['occurence']>1]
print(test_set2.shape)
# Out:
# (15427, 4)
# (18, 8)

# %%
#Extract duplicate rows
id1 = train_set2["smiles_canon"]
train_set2=train_set2[id1.isin(id1[id1.duplicated()])].sort_values("smiles_canon")
id2 = test_set2["smiles_canon"]
test_set2=test_set2[id2.isin(id2[id2.duplicated()])].sort_values("smiles_canon")

# %%
print(train_set2.shape)
print(test_set2.shape)
# Out:
# (15427, 4)
# (18, 8)

# %%
train_set2.reset_index(drop=True)
test_set2.reset_index(drop=True)
# Out:
#         ID                           Name  \
# 0    E-403         hydrocortisone_acetate
# 1   E-1004              Cortisone_Acetate
# 2    E-666          chenodeoxycholic_acid
# 3    E-665            hyodeoxycholic_acid
# 4    E-402                  dexamethasone
# 5    E-414                  betamethasone
# 6   E-1225    cis-1,2-Dimethylcyclohexane
# 7    E-828  trans-1,2-Dimethylcyclohexane
# 8    E-257        2,3-dimethyl-3-pentanol
# 9   E-1082        2,4-dimethyl-3-pentanol
# 10   E-544                    kasugamycin
# 11   E-944                    Karbutilate
# 12   E-973                    Hyoscyamine
# 13  E-1141                       atropine
# 14   E-145                         endrin
# 15  E-1128                       dieldrin
# 16   E-134    gamma-hexachlorocyclohexane
# 17  E-1283                        lindane
#
#                                                 InChI  \
# 0   InChI=1S/C23H30O6/c1-13(24)29-12-19(27)23(28)9...
# 1   InChI=1S/C23H30O6/c1-13(24)29-12-19(27)23(28)9...
# 2   InChI=1S/C24H40O4/c1-14(4-7-21(27)28)17-5-6-18...
# 3   InChI=1S/C24H40O4/c1-14(4-7-21(27)28)17-5-6-18...
# 4   InChI=1S/C22H29FO5/c1-12-8-16-15-5-4-13-9-14(2...
# 5   InChI=1S/C22H29FO5/c1-12-8-16-15-5-4-13-9-14(2...
# 6   InChI=1S/C8H16/c1-7-5-3-4-6-8(7)2/h7-8H,3-6H2,...
# 7   InChI=1S/C8H16/c1-7-5-3-4-6-8(7)2/h7-8H,3-6H2,...
# 8    InChI=1S/C7H16O/c1-5-7(4,8)6(2)3/h6,8H,5H2,1-4H3
# 9    InChI=1S/C7H16O/c1-5-7(4,8)6(2)3/h6,8H,5H2,1-4H3
# 10  InChI=1S/C14H21N3O3/c1-14(2,3)16-13(19)20-11-8...
# 11  InChI=1S/C14H21N3O3/c1-14(2,3)16-13(19)20-11-8...
# 12  InChI=1S/C17H23NO3/c1-18-13-7-8-14(18)10-15(9-...
# 13  InChI=1S/C17H23NO3/c1-18-13-7-8-14(18)10-15(9-...
# 14  InChI=1S/C12H8Cl6O/c13-8-9(14)11(16)5-3-1-2(6-...
# 15  InChI=1S/C12H8Cl6O/c13-8-9(14)11(16)5-3-1-2(6-...
# 16  InChI=1S/C6H6Cl6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
# 17  InChI=1S/C6H6Cl6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
#
#                        InChIKey  \
# 0   ITRJWOMZKQRYTA-UHFFFAOYSA-N
# 1   ITRJWOMZKQRYTA-UHFFFAOYSA-N
# 2   RUDATBOHQWOJDD-UHFFFAOYSA-N
# 3   RUDATBOHQWOJDD-UHFFFAOYSA-N
# 4   UREBDLICKHMUKA-UHFFFAOYSA-N
# 5   UREBDLICKHMUKA-UHFFFAOYSA-N
# 6   KVZJLSYJROEPSQ-UHFFFAOYSA-N
# 7   KVZJLSYJROEPSQ-UHFFFAOYSA-N
# 8   RFZHJHSNHYIRNE-UHFFFAOYSA-N
# 9   RFZHJHSNHYIRNE-UHFFFAOYSA-N
# 10  OWNAXTAAAQTBSP-UHFFFAOYSA-N
# 11  OWNAXTAAAQTBSP-UHFFFAOYSA-N
# 12  RKUNBYITZUJHSG-UHFFFAOYSA-N
# 13  RKUNBYITZUJHSG-UHFFFAOYSA-N
# 14  DFBKLUNHFCTMDC-UHFFFAOYSA-N
# 15  DFBKLUNHFCTMDC-UHFFFAOYSA-N
# 16  JLYXXMFPNIAWKQ-UHFFFAOYSA-N
# 17  JLYXXMFPNIAWKQ-UHFFFAOYSA-N
#
#                                                SMILES  Solubility  \
# 0   CC(=O)OCC(=O)C3(O)CCC4C2CCC1=CC(=O)CCC1(C)C2C(...       -4.30
# 1   CC(=O)OCC(=O)C3(O)CCC4C2CCC1=CC(=O)CCC1(C)C2C(...       -4.00
# 2     CC(CCC(O)=O)C3CCC4C2C(O)CC1CC(O)CCC1(C)C2CCC34C       -3.64
# 3   C1C(O)CC2CC(O)C3C4CCC(C(C)CCC(=O)O)C4(C)CCC3C2...       -3.82
# 4   C1(=O)C=C2CCC3C4CC(C)C(O)(C(=O)CO)C4(C)CC(O)C3...       -3.64
# 5   C1=CC(=O)C=C2CCC3C4CC(C)C(O)(C(=O)CO)C4(C)CC(O...       -3.77
# 6                                      C1C(C)C(C)CCC1       -4.27
# 7                                      C1C(C)C(C)CCC1       -4.33
# 8                                      CC(C)C(C)(O)CC       -0.85
# 9                                      CC(C)C(O)(C)CC       -1.22
# 10               CN(C)C(=O)Nc1cccc(OC(=O)NC(C)(C)C)c1       -2.93
# 11               CN(C)C(=O)Nc1cccc(OC(=O)NC(C)(C)C)c1       -2.93
# 12           O=C(OC(CC(N(C1C2)C)C2)C1)C(c(cccc3)c3)CO       -1.91
# 13           O=C(OC(CC(N(C1C2)C)C2)C1)C(c(cccc3)c3)CO       -2.12
# 14     ClC4=C(Cl)C5(Cl)C3C1CC(C2OC12)C3C4(Cl)C5(Cl)Cl       -6.18
# 15     ClC4=C(Cl)C5(Cl)C3C1CC(C2OC12)C3C4(Cl)C5(Cl)Cl       -6.29
# 16                     C(C(C(C(C1Cl)Cl)Cl)Cl)(C1Cl)Cl       -4.59
# 17                     C(C(C(C(C1Cl)Cl)Cl)Cl)(C1Cl)Cl       -4.60
#
#                                          smiles_canon  occurence
# 0   CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...          2
# 1   CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...          2
# 2     CC(CCC(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CCC12C          2
# 3     CC(CCC(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CCC12C          2
# 4   CC1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1(O...          2
# 5   CC1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1(O...          2
# 6                                          CC1CCCCC1C          2
# 7                                          CC1CCCCC1C          2
# 8                                      CCC(C)(O)C(C)C          2
# 9                                      CCC(C)(O)C(C)C          2
# 10               CN(C)C(=O)Nc1cccc(OC(=O)NC(C)(C)C)c1          2
# 11               CN(C)C(=O)Nc1cccc(OC(=O)NC(C)(C)C)c1          2
# 12                 CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2          2
# 13                 CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2          2
# 14     ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl          2
# 15     ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl          2
# 16                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl          2
# 17                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl          2

# %%
train_set2=train_set2[['smiles_canon','Solubility','occurence']]
test_set2=test_set2[['smiles_canon','Solubility','occurence']]

# %%
train_set2.reset_index(drop=True)
test_set2.reset_index(drop=True)
# Out:
#                                          smiles_canon  Solubility  occurence
# 0   CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...       -4.30          2
# 1   CC(=O)OCC(=O)C1(O)CCC2C3CCC4=CC(=O)CCC4(C)C3C(...       -4.00          2
# 2     CC(CCC(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CCC12C       -3.64          2
# 3     CC(CCC(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CCC12C       -3.82          2
# 4   CC1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1(O...       -3.64          2
# 5   CC1CC2C3CCC4=CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1(O...       -3.77          2
# 6                                          CC1CCCCC1C       -4.27          2
# 7                                          CC1CCCCC1C       -4.33          2
# 8                                      CCC(C)(O)C(C)C       -0.85          2
# 9                                      CCC(C)(O)C(C)C       -1.22          2
# 10               CN(C)C(=O)Nc1cccc(OC(=O)NC(C)(C)C)c1       -2.93          2
# 11               CN(C)C(=O)Nc1cccc(OC(=O)NC(C)(C)C)c1       -2.93          2
# 12                 CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2       -1.91          2
# 13                 CN1C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2       -2.12          2
# 14     ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl       -6.18          2
# 15     ClC1=C(Cl)C2(Cl)C3C4CC(C5OC45)C3C1(Cl)C2(Cl)Cl       -6.29          2
# 16                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl       -4.59          2
# 17                       ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl       -4.60          2

# %%
print(train_set2.shape)
print(test_set2.shape)
# Out:
# (15427, 3)
# (18, 3)

# %%
# Group by SMILES
grouped_train = train_set2.groupby('smiles_canon')
grouped_test = test_set2.groupby('smiles_canon')
# Filter groups where the maximum difference in solubility is less than or equal to 0.50
filtered_groups_train = grouped_train.filter(lambda x: x['Solubility'].max() - x['Solubility'].min() <= 0.50)
filtered_groups_test = grouped_test.filter(lambda x: x['Solubility'].max() - x['Solubility'].min() <= 0.50)

# %%
print(len(filtered_groups_train))
print(len(filtered_groups_test))
# Out:
# 14044
# 18

# %%
### In order to eavluate to threshold followed by the dataframe we can cross check the value of difference
grouped = filtered_groups_train.groupby('smiles_canon')['Solubility'].apply(lambda x: x.sort_values().tolist())

# Calculate differences in solubility within each group
diffs = grouped.apply(lambda x: [j - i for i, j in zip(x[:-1], x[1:])])

# Create a new DataFrame with SMILES, Solubility values, and differences
result = grouped.reset_index()
result.columns = ['smiles_canon', 'Solubility_Values']

# Add the differences as a new column
result['Differences'] = diffs.values

result
# Out:
#                                        smiles_canon  \
# 0               Br.CN(C)CCC=C1c2ccccc2Sc2ccc(F)cc21
# 1     Br.Oc1ccc2c(c1)C13CCCCC1C(C2)N(CCc1ccccc1)CC3
# 2                                     BrC(Br)(Br)Br
# 3                                         BrC(Br)Br
# 4                                    BrC(Br)C(Br)Br
# ...                                             ...
# 5683                                        c1cnoc1
# 5684                     c1coc(-c2nc3ccccc3[nH]2)c1
# 5685                                     c1nc[nH]n1
# 5686                               c1ncc2[nH]cnc2n1
# 5687                               c1ncc2n[nH]nc2n1
#
#                       Solubility_Values  \
# 0          [-5.603798043, -5.603798043]
# 1          [-4.833904011, -4.833904011]
# 2     [-3.157037902, -3.1400001, -3.14]
# 3          [-1.911295104, -1.91, -1.91]
# 4                 [-2.72, -2.710626523]
# ...                                 ...
# 5683              [0.3827, 0.383489897]
# 5684             [-3.414031277, -3.414]
# 5685         [0.788504777, 1.005834993]
# 5686                [0.619390837, 0.62]
# 5687                 [-0.2319, -0.2319]
#
#                                         Differences
# 0                                             [0.0]
# 1                                             [0.0]
# 2     [0.017037801999999935, 9.999999983634211e-08]
# 3                      [0.0012951039999999914, 0.0]
# 4                            [0.009373477000000019]
# ...                                             ...
# 5683                        [0.0007898970000000394]
# 5684                        [3.127699999971867e-05]
# 5685                           [0.2173302159999999]
# 5686                        [0.0006091630000000237]
# 5687                                          [0.0]
#
# [5688 rows x 3 columns]

# %%
# Group again by SMILES and calculate the mean of solubility
mean_solubility_df_train = filtered_groups_train.groupby('smiles_canon').mean().reset_index()
mean_solubility_df_test = filtered_groups_test.groupby('smiles_canon').mean().reset_index()

# %%
### Combining the dataframe with single entry and matching smiles and average the solubility values 

train_set=pd.concat([train_set1, mean_solubility_df_train], axis=0, ignore_index=True)
test_set=pd.concat([test_set1, mean_solubility_df_test], axis=0, ignore_index=True)

# %%
print(train_set.shape)
print(test_set.shape)
# Out:
# (19120, 3)
# (1282, 3)

# %%
matching_smiles = pd.merge(train_set[['smiles_canon']], test_set[['smiles_canon']], on='smiles_canon')['smiles_canon']

# Remove the matching SMILES from both DataFrames
df1_filtered = train_set[~train_set['smiles_canon'].isin(matching_smiles)]

# %%
matching_smiles
# Out:
# 0                          Sc1ncnc2nccnc12
# 1                             Oc1ccnc(S)n1
# 2                          Cc1cc(O)nc(S)n1
# 3        O=c1[nH]cnc2c1ncn2C1OC(CO)C(O)C1O
# 4       C1CCC([Sn](C2CCCCC2)C2CCCCC2)CC1.O
#                        ...
# 1178                              c1ccnnc1
# 1179                               c1ccoc1
# 1180                               c1ccsc1
# 1181                        c1cnc2ncncc2n1
# 1182                              c1cncnc1
# Name: smiles_canon, Length: 1183, dtype: object

# %%
df1_filtered
# Out:
#                                         smiles_canon  Solubility  occurence
# 0                     O=C1c2ccccc2C(=O)c2c(Cl)cccc21   -5.540000        1.0
# 1                        NC(N)=NS(=O)(=O)c1ccc(N)cc1   -1.984970        1.0
# 2      CCC1C(N)CN1c1cc2c(cc1F)c(=O)c(C(=O)O)cn2C1CC1   -3.912000        1.0
# 3              CCC1(CC)OC(=O)c2cc([N+](=O)[O-])ccc21   -3.656000        1.0
# 4                               O=C1C=Cc2ccccc2C1=NO   -2.937000        1.0
# ...                                              ...         ...        ...
# 19115                                        c1cnoc1    0.383095        2.0
# 19116                     c1coc(-c2nc3ccccc3[nH]2)c1   -3.414016        2.0
# 19117                                     c1nc[nH]n1    0.897170        2.0
# 19118                               c1ncc2[nH]cnc2n1    0.619695        2.0
# 19119                               c1ncc2n[nH]nc2n1   -0.231900        2.0
#
# [17937 rows x 3 columns]

# %%
df_concat = pd.concat([train_set, test_set])

# Drop duplicates SMILES
df_unique = df_concat.drop_duplicates(subset='smiles_canon', keep=False)

# Split the unique rows back into two DataFrames
df1_filtered = df_unique[df_unique['smiles_canon'].isin(train_set['smiles_canon'])].reset_index(drop=True)

# %%
df1_filtered
# Out:
#                                         smiles_canon  Solubility  occurence
# 0                     O=C1c2ccccc2C(=O)c2c(Cl)cccc21   -5.540000        1.0
# 1                        NC(N)=NS(=O)(=O)c1ccc(N)cc1   -1.984970        1.0
# 2      CCC1C(N)CN1c1cc2c(cc1F)c(=O)c(C(=O)O)cn2C1CC1   -3.912000        1.0
# 3              CCC1(CC)OC(=O)c2cc([N+](=O)[O-])ccc21   -3.656000        1.0
# 4                               O=C1C=Cc2ccccc2C1=NO   -2.937000        1.0
# ...                                              ...         ...        ...
# 17932                                        c1cnoc1    0.383095        2.0
# 17933                     c1coc(-c2nc3ccccc3[nH]2)c1   -3.414016        2.0
# 17934                                     c1nc[nH]n1    0.897170        2.0
# 17935                               c1ncc2[nH]cnc2n1    0.619695        2.0
# 17936                               c1ncc2n[nH]nc2n1   -0.231900        2.0
#
# [17937 rows x 3 columns]

# %%
# savinf the combine 6 dataset 
train_set.to_csv('data/combined_data6.csv')

# %%
### Remove the smiles from train dataset with matching test dataset...
smiles_train_canon=train_set.smiles_canon
smiles_test_canon=test_set.smiles_canon

# %%
overlap1 = 0
for x in smiles_train_canon:
    if x in smiles_test_canon:
        overlap1+=1
print("%i of the train molecules are in the test set"%(overlap1))

overlap2 = 0
for x in smiles_test_canon:
    if x in smiles_train_canon:
        overlap2+=1
print("%i of the test molecules are in the train set"%(overlap2))
# Out:
# 0 of the train molecules are in the test set
# 0 of the test molecules are in the train set

# %%
Match_rows = pd.merge(test_set, train_set, on=['smiles_canon'], how='inner')
#mergedStuff.head()
print(len(Match_rows))
# Out:
# 1183

# %%
### Finding the matching smiles in the train dataset..
cond = train_set['smiles_canon'].isin(Match_rows['smiles_canon'])

#### Dropping the smiles which is same and making dataframe with uniques smiles and no smiles same in ttrain  dataset 
train_set.drop(train_set[cond].index, inplace = True)

# %%
print(train_set.shape)
print(test_set.shape)
# Out:
# (17937, 3)
# (1282, 3)

# %%
### Cross check in order to find that any matching smiles exist in the train dataset with test dataset
Match_rows = pd.merge(test_set, train_set, on=['smiles_canon'], how='inner')
#mergedStuff.head()
print(len(Match_rows))
# Out:
# 0

# %%
train_set.reset_index(drop=True)
# Out:
#                                         smiles_canon  Solubility  occurence
# 0                     O=C1c2ccccc2C(=O)c2c(Cl)cccc21   -5.540000        1.0
# 1                        NC(N)=NS(=O)(=O)c1ccc(N)cc1   -1.984970        1.0
# 2      CCC1C(N)CN1c1cc2c(cc1F)c(=O)c(C(=O)O)cn2C1CC1   -3.912000        1.0
# 3              CCC1(CC)OC(=O)c2cc([N+](=O)[O-])ccc21   -3.656000        1.0
# 4                               O=C1C=Cc2ccccc2C1=NO   -2.937000        1.0
# ...                                              ...         ...        ...
# 17932                                        c1cnoc1    0.383095        2.0
# 17933                     c1coc(-c2nc3ccccc3[nH]2)c1   -3.414016        2.0
# 17934                                     c1nc[nH]n1    0.897170        2.0
# 17935                               c1ncc2[nH]cnc2n1    0.619695        2.0
# 17936                               c1ncc2n[nH]nc2n1   -0.231900        2.0
#
# [17937 rows x 3 columns]

# %%
print(train_set.shape)
print(test_set.shape)
# Out:
# (17937, 3)
# (1282, 3)

# %%
### Saving the data to the disk 
train_set.to_csv('data/unique_train4_new24_new.csv')
test_set.to_csv('data/unique_test_new24.csv')

# %%
train_smiles = set(train_set['smiles_canon'])
test_smiles = set(test_set['smiles_canon'])
overlap = train_smiles.intersection(test_smiles)

if overlap:
    print("There are overlapping smiles between the training and test datasets:")
    print(overlap)
else:
    print("No overlapping smiles between the training and test datasets.")
# Out:
# No overlapping smiles between the training and test datasets.

# %%
#### End here ....
